# %% [markdown]
# <a href="https://colab.research.google.com/github/Mu-Hasnain/-BashForAutomation-/blob/main/IntroToBashScripting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.1- What is Bash?**
# ### **Learning Bash Scripting**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **That shows us what version of Bash is installed.**
#
# ![image.png](data:image/png;base64,...)
#
# **If you Don't have Bash installed, you can usually get it from your distro's package manager.**

# %% [markdown]
# **When we open up a terminal window, the user's default shell opens in that window.**
# **we can see what the default shell is using echo $SHELL,**
#
# ![image.png](data:image/png;base64,...)
#
# And here I can see that mine is Bash

# %% [markdown]
# **If yours isn't, you can change it with a *chsh* command.**
# ![image.png](data:image/png;base64,...)
#
# Or just run Bas to moe into a Bash shell.

# %% [markdown]
# #**1.2- Pipes and redirection**
#
# Working in Bash we'll often need to control where output and input for commands are sent.
# There are two concepts to deal with this piping and redirection.
# - > Piping takes the result of one process and sends it to another process as though the output of the first process were connected to the input of the second with a tube or pipe.
# Instead of displaying the output of the first process on the standard output,  the output is sent along to the following process without being displayed on the screen.
#
# ![image.png](data:image/png;base64,...)
#
# **For example, we could use the cat command to take a look at the systems dictionary file which is really long.**
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# **And that's a bunch of stuff,  it would be nice to take that output and display it page by page.**
# ###**We can do this by piping the output of ls into the less command.**
#
# ![image.png](data:image/png;base64,...)
#
# press q to quit.

# %% [markdown]
# **We could also use the word count command or wc to count the number of lines in this file, by sending the output of cat to wc through a pipe.**
#
# ![image.png](data:image/png;base64,...)
#
# **You can string many commands together with pipes, as long as it makes sense for the output of one command to be sent as input for the next.**
#
# **Pipes are important in Bash scripting because they let us piece together commands in order to build custom flows.**
#
# **Pipes are very often used with tools like grep, awk, sed, and cat which allow us to transform text from files or from the output of commands in useful ways.**

# %% [markdown]
# **Redirection on the other hand works with the standard input
# standard output and standard error.**
#
# **That is the input from the command line environment the output to it and the errors that arise when something goes wrong.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **A very basic example of redirection would be to take the output of a command like ls and send it to a file instead of to the screen at the standard input.**
#
# **To do that, use the greater than sign and provide a place for the output to go in this case abc.txt.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **using two greater than signs, we'll add the information on-to the end of their existing file.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.3- Bash builtin and other commands
#
# **- When we're working with a shell, with bash, in this case, most of what we do involves running commands.**
#
# **These commands are things like ls, rm, grep, arc, and pretty much anything else you commonly use a shell to run.
# These commands are separate from bash, they're separate programs that are installed on the system.**
#
# **But bash includes a few built-ins or commands that are part of the bash built right into it, which we can use as well.**
#
# **Sometimes these built-ins are unique to bash, and sometimes they have the same name as other commands on the system.**
#
# **There's a list of built-ins in the bash man pages.**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Doing this will allow the command version to run instead.
# we see that the shell will use the command version instead of the built-in.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##1.4- Brackets and braces in Bash
#
# **Before we dig into Bash, I want to take a moment to talk about those curvy kinds of semicircular characters that are so important to programmers:**
#
# **:: parentheses, braces, and brackets.**
#
# ** There are many names for each of these sets of characters, like circle brackets or round brackets, curly braces or flower brackets, and square brackets and closed brackets. **
#
# -> Parentheses are often used for enclosing conditions and for function parameters.
#
# -> Braces are used for function bodies and objects. And
#
# -> brackets are used for a list or array notation.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **In Bash, that's often a little different, and in many cases, parentheses,  braces, and brackets act as commands themselves.**
#
# **So it can take a little getting used to if you're coming from other languages.**
#
# **If Bash is the first language you're learning, you won't have that overhead to deal with.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1.5- Bash expansions and substitutions**
# **When we're working with Bash, either at the command line or in a script, we'll often need to use values we don't know, things like a path to the user's home folder, a piece of user-provided information, or the result of a calculation that's based on something we can't foresee.**
#
# **Bash provides us with a way to represent these values using expansions and substitutions.**
#
# **These are interpreted when they run and they replace themselves with a value or a set of values.**
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
# **We can see that with echo ~, and there's my home directory.**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tilde expansion is useful when we're scripting because if we want to do something in a user's home directory, which is a pretty important place, we can do that without knowing their username.**
#
# **Tilde just represents whatever the current user's home directory is.**
#
# **Another useful tilde expansion trick is that the tilde followed by a dash or a minus represents a Bash variable called OLDPWD, which is the directory that you were just in if you've recently changed directories.**

# %% [markdown]
# # **1.6- Brace expansion**
#
# **Another useful type of expansion is called brace expansion.**
#
# **This is written with braces around an expression and it lets us substitute items from a list of values separated by commas, or ranges of numbers or letters in a given pattern, separated by two periods, or dots.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Brace expansion is often used when we need to keep part of a path the same but replace a little piece of it.**
# #**For example:**
# **If we wanted to create a file inside of each of three different directory trees, where only part of the path needs to change each time.**
#
# **Or we could use it to provide a set of values to use in the same part of a string more generally.**
#
# **The other form of brace expansion, which creates a sequence of numbers or letters is often used when working with sequential items.**
#
# ![image.png](data:image/png;base64,...)
#
# And brace expansion can be used as a kind of shorthand when working with commands, too.

# %% [markdown]
# # **1.7- Parameter expanssion**
#
# **Parameter expanssion: lets us recall stored values and transform them in various ways.
# This is usually represented by a dollar sign($) and a set of braces.**
#
# **Though sometimes we'll see it without the braces.**
#
# **The most straightforward use of parameter expansion is setting a value and then retrieving it.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We set a parameter equal to a value and then use the dollar sign with the name of that parameter to retrieve the value later.
#
# Parameter expansion also often features braces and those are used to make it clear what parameter is being used and to keep the shell from getting confused about nearby words or characters.
#
# **As an example here,**
# ![image.png](data:image/png;base64,...)
#
# To retrieve that value here at te command line, just hit echo dollar sign and the name of that parameter.
# And there's my value that I assigned to that parameter.

# %% [markdown]
# Parameter expansion can also be used to manipulate the stored value when it's used, transforming it in various ways, like just using part of the value before it's used.
# **For example**
# ![image.png](data:image/png;base64,...)
#
# **I can write echo ${greeting:6} and get the value of the parameter.
# Starting with the character at position six in the string.**
#
# **Or: echo ${greeting:6:3} to get the value starting at position six and then running for three characters from that point.**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# One more parameter expansion feature that's useful though is pattern substitution.
#
# This lets us retrieve a value and transform it based on a pattern as we might do if we want to replace a particular word or character for some reason, I write:- $ echo ${reeting/there/everybody}
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1.8- What makes a shell script a shell script?**
#
# The beauty of shell scripting is that we don't need a complex
# development environment to get started.
# To make a shell script that acts like a system command, we do need to do a few things.
# First, we create a text file in our favorite editor.
# In the terminal, type in vi ~/script.sh then hit Enter.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We've named it script.sh, so that vi will do syntax highlighting for us.
# Script don't have to be named like this, but it makes it nicer for text editors.
# Syntax highlighting makes debugging easier.
# For the next step, we need to edit the text file and make the first line point to the shell interpreter.
#
# We can do this by pointing it directly at the interpreter using an absolute path.
#
# **When in insert mode by pressing 'i' key and then add #!/bin/bash**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this case, we're specifying an absolute path to the bash interpreter executable.
#
# **We can also use a second form. Change it to '#!/usr/bin/env bash'**
#
# ![image.png](data:image/png;base64,...)
# In this case, we use the env command to search the system path for the bash interpreter and executed it there
# The advantage is that it could b in a different location and it will still work.
# **Let's add one line of text to our script.**
#
# ![image.png](data:image/png;base64,...)
# and save / exit by pressing Esc + :x! and hit Enter:
# After we added code and save our script, we need to change the permission and make it executable.
#
# **Type in chmod u+x filename in this case script.sh and hit Enter.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The last thing we would do to make it seamless is to put our command in the system path.
# when you use the logs in, it directory's added to the system path specifically for that user.
# That directory is ~/bin.
# We need to create this directory first.
#
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# Note that none of these steps are actually required to run a text file as a shell script.
#
# You can create a text file privated as an argument to bash it will run.
# **For instance, type echo 'echo this is a shell script' > ~/bin/script2.sh and hit Enter.**
#
# **Now let's run it by providing it as an argument to bash.**
# ![image.png](data:image/png;base64,...)
#
# And it runs even without execute permissions.

# %% [markdown]
# # **1.9- Using bash debugging mode**
# Bash doesn't have the complex debugging facilities that other languages have.
# But knowing right up front that we can watch what Bash is doing, helps.
# We have two methods of using Bash's debugging mode.
# we can provide the -x option to Bash when we call a script, which looks like this.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# We see more information on the screen.
# The left justified lines are printed on the screen, this is standard out.
# The lines that start with the + symbol are the debugger lines.
#
# The debugger shows the value of the variablse, the depth of code blocks, and the output.
#
# Now, lets add debugging inside of the the script.
# First we'll duplicate our loop and change it a bit

# %% [markdown]
# **Now, add debugging code, just for the first loop.
# Before the first loop, type in, set -x, and just immediately after the first loop, type in, set +x.**
#
# **It's counterintuitive, but -x turns debugging on, and +x turns it off.
# Now, save and exit.**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's run our script now.
# First, we'll add execute permissions.
#
# **Type in, chmod u+x debugger.sh, and hit Enter.**
# ![image.png](data:image/png;base64,...)
#
# **Now, type in, ./debugger.sh and hit Enter again**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can see only the first loop is being debugged.
# I recommend using debugging as you're writing scripts, as it will help you catch errors before you get too far.
#
# However, it's so verbose, that I only use it for portions of code.
# Also, the debugger sends the debug information to standard error, so if you want to see normal output on the screen, and save the debugger output to a file, you can do this.
#
# **You can type in , 2 > debug.txt, and hit Enter.**
#
#
# ![image.png](data:image/png;base64,...)
#
# *Now the debNug.txt file has all the data from the debugger, and you can view it with any text viewer, such as CAT.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There's a third-party Bash debugger that's more powerful.
# You can find it at bashdb.sourceforge.net.
# It's an interactive tool that allows you to step through code.

# %% [markdown]
# # **1.10- Bash Variable Scope**
# One of the most common pitfalls to writing Bash shell scripts is unknown variable scope.
#
# Bash, unlike many other languages, doesn't have variable scope by default.
#
# we have four levels of variable scope.
# ![image.png](data:image/png;base64,...)
#
# 1-The first type of variable scope is the global environmental variable which the entire OS can see.
# These variables are set in the system when it starts.
# Changes to this environment can be made by editing the shell startup script such as the etc profile, etc bashrc, or the Bash_profile and .bashrc files on the user home directory.
# Be sure to use the export command so the variables are accessible by any sub-processes like shells you will start or scripts you will run.
#
# ![image.png](data:image/png;base64,...)
#
# 2- The second type of variable scope is variables that are local to a script, which can be seen by any function, command or statement in the script.
# Anytime we create a variable it will be in this category by default.
#
# ![image.png](data:image/png;base64,...)
#
# 3- The third type of variable scope is variable that are local to a script and all subprocesses and subshells run by the script.by all sub-processes by using the export command.
#
# ![image.png](data:image/png;base64,...)
#
# 4- And lastly, local variables which are used within code blocks and can only be seen within that block.
# To make a variable local to a code block we do use the local command .
#
# ![image.png](data:image/png;base64,...)
